# %%
# %run /Workspace/Users/andreasdedus@gmail.com/First-Lake-House-Project/bike_lakehouse/Silver/helper_functions

# %%
df, TABLE_NAME = df_init("workspace.bronze.sales_details")

# %% [markdown]
# # Data normalization

# %% [markdown]
# ## Column renaming

# %%
new_names = {
    'sls_ord_num': 'order_id',
    'sls_prd_key': 'product_id',
    'sls_cust_id': 'customer_id',
    'sls_order_dt': 'order_date',
    'sls_ship_dt': 'ship_date',
    'sls_due_dt': 'due_date',
    'sls_sales': 'sales',
    'sls_quantity': 'quantity',
    'sls_price': 'price'
}
df = df.withColumnsRenamed(new_names)

# %% [markdown]
# ## Date normalization

# %%
date_cols = ["order_date", "ship_date", "due_date"]

for c in date_cols:
    df = df.withColumn(c, try_to_date(col(c), "yyyyMMdd"))

# %%
writing_silver_table(df, TABLE_NAME)
