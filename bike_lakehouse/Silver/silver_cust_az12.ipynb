# %%
# %run /Workspace/Users/andreasdedus@gmail.com/First-Lake-House-Project/bike_lakehouse/Silver/helper_functions

# %%
df, TABLE_NAME = df_init("workspace.bronze.cust_az12")

# %% [markdown]
# # Transform and normalize data

# %% [markdown]
# ## Rename columns for better readability

# %%
df = df.withColumnsRenamed({"CID": "customer_id", "BDATE": "birth_date","GEN": "gender"})

# %% [markdown]
# ## Replace single char values for better readability

# %%
df = replace_gender(df, "gender")

# %% [markdown]
# ## Write to write to silver table

# %%
from pyspark.sql.functions import to_date
df = df.withColumn("birth_date", to_date("birth_date", "yyyy-MM-dd"))

writing_silver_table(df, TABLE_NAME)
