# %%
# %run /Workspace/Users/andreasdecarvalho.prog@gmail.com/First-Lake-House-Project/bike_lakehouse/Silver/silver_functions

# %%
df, TABLE_NAME = df_init("workspace.bronze.cust_info")

# %% [markdown]
# # Data normalization

# %% [markdown]
# ## Column renaming

# %%
new_names = {
    "cst_id": "id",
    "cst_key": "key",
    "cst_firstname": "firstname",
    "cst_lastname": "lastname",
    "cst_marital_status": "marital_status",
    "cst_gndr": "gender",
    "cst_create_date": "create_date"}

df = df.withColumnsRenamed(new_names)

# %% [markdown]
# ## Parse single char values to full words

# %%
df = replace_gender(df, "gender")
df = df.replace({"S": "single", "M": "married"}, subset="marital_status")

# %% [markdown]
# ## Writing to silver table

# %%
writing_silver_table(df, TABLE_NAME)
