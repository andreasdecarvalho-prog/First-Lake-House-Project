# %%
# %run /Workspace/Users/andreasdedus@gmail.com/First-Lake-House-Project/bike_lakehouse/Silver/helper_functions

# %%
df, TABLE_NAME = df_init("workspace.bronze.prd_info")

# %% [markdown]
# ## Column renaming

# %%
new_names = {
  "prd_nm": "prd_name",
  "prd_start_dt": "prd_start_date",
  "prd_end_dt": "prd_end_date"
}

df = df.withColumnsRenamed(new_names)

# %% [markdown]
# # Writing to silver table

# %%
writing_silver_table(df, TABLE_NAME)
