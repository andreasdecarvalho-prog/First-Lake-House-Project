# %%
files = dbutils.fs.ls("/Workspace/Users/andreasdecarvalho.prog@gmail.com/First-Lake-House-Project/bike_lakehouse/Silver")

for f in files:
    file_type = "directory" if f.name.endswith("/") else "file"
    p = f.path.split("dbfs:")[1]
    if file_type == "file":
        dbutils.notebook.run(p, 60)
